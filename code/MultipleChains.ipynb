# %%
from operator import itemgetter

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough
from langchain_anthropic import ChatAnthropic

from rich.console import Console
from rich.markdown import Markdown

gpt4 = ChatOpenAI(model="gpt-4o")
claud3 = ChatAnthropic(model='claude-3-opus-20240229')

console = Console()

prompt1 = ChatPromptTemplate.from_template(
    "Develop a business or product concept and around the following topic: {topic}. List dos and don'ts for the concept. Include a brief description of the concept and the target audience, how to price and market the business or product, and how to make it stand out from competitors. The output should be markdown."
)
prompt2 = ChatPromptTemplate.from_template(
    "Create a milestone plan, a gant chart, a raid chart and a task table. based on the following markdown document: {markdown} "
)

model = ChatOpenAI()

chain1 = prompt1 | model | StrOutputParser()

chain2 = (
    {"markdown": chain1, "topic": RunnablePassthrough() }
    | prompt2
    | model
    | StrOutputParser()
)

# %%
first_prompt = ChatPromptTemplate.from_template(
    "Develop a business or product concept and around the following topic: {topic}. List dos and don'ts for the concept. Include a brief description of the concept and the target audience, how to price and market the business or product, and how to make it stand out from competitors. The output should be markdown."
)
second_prompt = ChatPromptTemplate.from_template(
    "Create a milestone plan, a gant chart, a raid chart and a task table. based on the following markdown document: {markdown} "
)

first_chain =  prompt1 | claud3 | StrOutputParser()

second_chain = second_prompt | model | StrOutputParser()

complete_chain = ({
    "topic": itemgetter("topic"),
    "markdown": first_chain
    }
    | RunnablePassthrough.assign(plans=second_chain)
)


complete = complete_chain.invoke({"topic": "mobile app for personal decision making."})

complete_md = Markdown(complete['markdown'])
console.print(complete_md)

print("----------------------------")

plans_md = Markdown(complete['plans'])
console.print(plans_md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                     Mobile App for Personal Decision Making                                     ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#                                                 Concept Description
#
# The mobile app, named "DecisionMate," is designed to assist users in making personal decisions by providing a
# structured approach to decision-making. The app guides users through a step-by-step process, helping them clarify
# their goals, evaluate options, and make informed choices.
#
#
#                                                   Target Audience
#
# The target audience for DecisionMate includes:
#
#  • Young adults (18-35) who face numerous life decisions
#  • Professionals seeking to make better career choices
#  • Individuals struggling with indecisiveness or decision fatigue
#
#
#                                                Pricing and Marketing
#
#  • Offer a free trial period to attract users and demonstrate the app's value
#  • Implement a freemium model with basic features available for free and premium features unlocked through a
#    subscription (e.g., $4.99/month or $49.99/year)
#  • Promote the app through social media campaigns, influencer partnerships, and targeted online advertising
#  • Collaborate with mental health professionals and life coaches to gain endorsements and expand reach
#
#
#                                             Unique Selling Proposition
#
#  • Personalized decision-making assistance based on user preferences and goals
#  • Integration with calendar and task management apps for seamless implementation of decisions
#  • In-app community for users to share experiences and seek advice from others
#  • Partnership with certified life coaches for premium users to receive one-on-one guidance
#
#
#                                                         Dos
#
#  • Focus on creating a user-friendly and intuitive interface
#  • Ensure data privacy and security to build trust with users
#  • Continuously update the app based on user feedback and emerging decision-making techniques
#  • Develop engaging content, such as articles and videos, to educate users on effective decision-making strategies
#
#
#                                                       Don'ts
#
#  • Don't overwhelm users with too many features or complex decision-making models
#  • Avoid making claims that the app can solve all decision-making challenges
#  • Don't neglect the importance of human interaction and encourage users to seek support from friends, family, or
#    professionals when needed
#  • Don't rely solely on algorithms; incorporate human expertise to provide personalized guidance
#
# By focusing on a target audience, offering a unique solution, and continuously improving the app based on user
# needs, DecisionMate can stand out in the market and help individuals make better personal decisions.
# ----------------------------
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                 Milestone Plan                                                  ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#   1 Market Research and Analysis
#   2 App Development and Testing
#   3 Pricing Strategy Implementation
#   4 Marketing and Promotion Campaign
#   5 Launch of Free Trial Period
#   6 User Feedback and App Updates
#   7 Freemium Model Rollout
#   8 Collaboration with Mental Health Professionals
#   9 Integration with Calendar and Task Management Apps
#  10 Community Building and Engagement
#  11 Premium Features Launch
#  12 Partnership with Certified Life Coaches
#  13 Continuous App Improvement
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                   Gantt Chart                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Task                                                 Start Date   End Date     Duration
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Market Research and Analysis                         01/01/2022   01/15/2022   15 days
#   App Development and Testing                          01/16/2022   02/28/2022   6 weeks
#   Pricing Strategy Implementation                      03/01/2022   03/15/2022   15 days
#   Marketing and Promotion Campaign                     03/16/2022   04/30/2022   6 weeks
#   Launch of Free Trial Period                          05/01/2022   05/15/2022   15 days
#   User Feedback and App Updates                        05/16/2022   06/15/2022   1 month
#   Freemium Model Rollout                               06/16/2022   06/30/2022   15 days
#   Collaboration with Mental Health Professionals       07/01/2022   07/15/2022   15 days
#   Integration with Calendar and Task Management Apps   07/16/2022   08/15/2022   1 month
#   Community Building and Engagement                    08/16/2022   09/15/2022   1 month
#   Premium Features Launch                              09/16/2022   09/30/2022   15 days
#   Partnership with Certified Life Coaches              10/01/2022   10/15/2022   15 days
#   Continuous App Improvement                           10/16/2022   12/31/2022   2.5 months
#
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                   RAID Chart                                                    ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Risk                  Impact   Probability   Mitigation
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Low User Adoption     High     Medium        Offer incentives for early adopters
#   Technical Issues      High     High          Conduct thorough testing before launch
#   Competition           High     High          Differentiate through unique features
#   Data Privacy Breach   High     Low           Implement strict security measures
#
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                   Task Table                                                    ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Task                               Description                                        Owner         Status
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Market Research and Analysis       Conduct surveys and analyze market trends          Marketing     In Progress
#   App Development and Testing        Develop app features and perform testing           Development   In Progress
#   Pricing Strategy Implementation    Determine pricing tiers and subscription model     Sales         Not Started
#   Marketing and Promotion Campaign   Plan social media campaigns and influencer         Marketing     Not Started
#                                      partnerships
#   Launch of Free Trial Period        Offer free trial period to attract users           Sales         Not Started

# %%
complete
# Out:
# {'topic': 'mobile app for personal decision making.',
#  'markdown': '# Mobile App for Personal Decision Making\n\n## Concept Description\nThe mobile app, named "DecisionMate," is designed to assist users in making personal decisions by providing a structured approach to decision-making. The app guides users through a step-by-step process, helping them clarify their goals, evaluate options, and make informed choices.\n\n## Target Audience\nThe target audience for DecisionMate includes:\n- Young adults (18-35) who face numerous life decisions\n- Professionals seeking to make better career choices\n- Individuals struggling with indecisiveness or decision fatigue\n\n## Pricing and Marketing\n- Offer a free trial period to attract users and demonstrate the app\'s value\n- Implement a freemium model with basic features available for free and premium features unlocked through a subscription (e.g., $4.99/month or $49.99/year)\n- Promote the app through social media campaigns, influencer partnerships, and targeted online advertising\n- Collaborate with mental health professionals and life coaches to gain endorsements and expand reach\n\n## Unique Selling Proposition\n- Personalized decision-making assistance based on user preferences and goals\n- Integration with calendar and task management apps for seamless implementation of decisions\n- In-app community for users to share experiences and seek advice from others\n- Partnership with certified life coaches for premium users to receive one-on-one guidance\n\n## Dos\n- Focus on creating a user-friendly and intuitive interface\n- Ensure data privacy and security to build trust with users\n- Continuously update the app based on user feedback and emerging decision-making techniques\n- Develop engaging content, such as articles and videos, to educate users on effective decision-making strategies\n\n## Don\'ts\n- Don\'t overwhelm users with too many features or complex decision-making models\n- Avoid making claims that the app can solve all decision-making challenges\n- Don\'t neglect the importance of human interaction and encourage users to seek support from friends, family, or professionals when needed\n- Don\'t rely solely on algorithms; incorporate human expertise to provide personalized guidance\n\nBy focusing on a target audience, offering a unique solution, and continuously improving the app based on user needs, DecisionMate can stand out in the market and help individuals make better personal decisions.',
#  'plans': '# Milestone Plan\n\n1. Market Research and Analysis\n2. App Development and Testing\n3. Pricing Strategy Implementation\n4. Marketing and Promotion Campaign\n5. Launch of Free Trial Period\n6. User Feedback and App Updates\n7. Freemium Model Rollout\n8. Collaboration with Mental Health Professionals\n9. Integration with Calendar and Task Management Apps\n10. Community Building and Engagement\n11. Premium Features Launch\n12. Partnership with Certified Life Coaches\n13. Continuous App Improvement\n\n# Gantt Chart\n\n| Task                         | Start Date | End Date   | Duration |\n|------------------------------|------------|------------|----------|\n| Market Research and Analysis | 01/01/2022 | 01/15/2022 | 15 days  |\n| App Development and Testing  | 01/16/2022 | 02/28/2022 | 6 weeks  |\n| Pricing Strategy Implementation | 03/01/2022 | 03/15/2022 | 15 days |\n| Marketing and Promotion Campaign | 03/16/2022 | 04/30/2022 | 6 weeks |\n| Launch of Free Trial Period  | 05/01/2022 | 05/15/2022 | 15 days |\n| User Feedback and App Updates | 05/16/2022 | 06/15/2022 | 1 month |\n| Freemium Model Rollout       | 06/16/2022 | 06/30/2022 | 15 days |\n| Collaboration with Mental Health Professionals | 07/01/2022 | 07/15/2022 | 15 days |\n| Integration with Calendar and Task Management Apps | 07/16/2022 | 08/15/2022 | 1 month |\n| Community Building and Engagement | 08/16/2022 | 09/15/2022 | 1 month |\n| Premium Features Launch       | 09/16/2022 | 09/30/2022 | 15 days |\n| Partnership with Certified Life Coaches | 10/01/2022 | 10/15/2022 | 15 days |\n| Continuous App Improvement    | 10/16/2022 | 12/31/2022 | 2.5 months |\n\n# RAID Chart\n\n| Risk               | Impact | Probability | Mitigation                                |\n|--------------------|--------|-------------|-------------------------------------------|\n| Low User Adoption  | High   | Medium      | Offer incentives for early adopters       |\n| Technical Issues   | High   | High        | Conduct thorough testing before launch    |\n| Competition        | High   | High        | Differentiate through unique features     |\n| Data Privacy Breach| High   | Low         | Implement strict security measures        |\n\n# Task Table\n\n| Task                         | Description                                                | Owner       | Status      |\n|------------------------------|------------------------------------------------------------|-------------|-------------|\n| Market Research and Analysis | Conduct surveys and analyze market trends                 | Marketing   | In Progress |\n| App Development and Testing  | Develop app features and perform testing                  | Development | In Progress |\n| Pricing Strategy Implementation | Determine pricing tiers and subscription model           | Sales       | Not Started |\n| Marketing and Promotion Campaign | Plan social media campaigns and influencer partnerships | Marketing   | Not Started |\n| Launch of Free Trial Period  | Offer free trial period to attract users                  | Sales       | Not Started |'}

# %%
output = chain2.invoke({"topic": "Web scraping product prices"})
gpt_md = Markdown(output)
console.print(gpt_md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                 Milestone Plan:                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#  1 Research and Analysis:
#     • Conduct market research on web scraping tools and pricing comparison websites.
#     • Analyze competitors and their features.
#     • Define target audience and user requirements.
#  2 Development:
#     • Design user interface for the web scraping tool.
#     • Develop web scraping algorithms to extract pricing information.
#     • Implement additional features such as price alerts and price history tracking.
#  3 Testing and Quality Assurance:
#     • Conduct thorough testing to ensure accuracy of pricing information.
#     • Test user interface for usability and functionality.
#     • Address any bugs or issues identified during testing.
#  4 Marketing and Launch:
#     • Develop pricing strategy and subscription model.
#     • Create marketing materials and online advertising campaigns.
#     • Launch the web scraping tool and track user engagement.
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Gantt Chart:                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Task                            Start Date   End Date     Duration
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Research and Analysis           01/01/2023   01/15/2023   2 weeks
#   Development                     01/16/2023   02/28/2023   6 weeks
#   Testing and Quality Assurance   03/01/2023   03/15/2023   2 weeks
#   Marketing and Launch            03/16/2023   04/15/2023   1 month
#
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                   RAID Chart:                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Risk               Impact   Likelihood   Mitigation Strategy
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Legal issues       High     Medium       Consult legal experts and comply with laws.
#   Data privacy       High     High         Implement encryption and secure data storage.
#   Technical issues   High     High         Conduct regular testing and debugging.
#   Competitor         Medium   Low          Differentiate with unique features and pricing.
#
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                   Task Table:                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#   Task                              Description                                     Assigned To       Status
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Research and Analysis             Conduct market research and analyze             Project Manager   In Progress
#                                     competitors to define target audience and
#                                     user requirements.
#   Design User Interface             Develop user-friendly interface for the web     UI/UX Designer    Not Started
#                                     scraping tool.
#   Develop Web Scraping Algorithms   Implement algorithms to extract pricing         Developer         Not Started
#                                     information from e-commerce websites.
#   Testing and Quality Assurance     Conduct testing to ensure accuracy and          QA Tester         Not Started
#                                     functionality of the tool.
#   Marketing Campaign                Develop pricing strategy, marketing             Marketing Team    Not Started
#                                     materials, and launch the web scraping tool.
